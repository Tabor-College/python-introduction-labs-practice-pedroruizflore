# %%
#1. Python Executes Step-by-Step
print("A")
print("B")
print("C")
# Out:
# A
# B
# C

# %% [markdown]
# It prints first A, then print C as the last one.

# %%
#2. Names and Objects
x = 10
y = x
x = 20
print(y)
# Out:
# 10

# %% [markdown]
# It's printed x first.

# %%
#3 . Execution Over Time
x = 5
x = x + 1
print(x)
# Out:
# 6

# %% [markdown]
# It's printed the result of the equation - "6"

# %%
#4. Execution Spaces (Functions)
def add (a, b):
  print("inside")
  return a + b
print("before")
add(2 , 3)
print("after")
# Out:
# before
# inside
# after

# %% [markdown]
# Before, inside, after

# %%
#5. Function Return
def make():
  x = [1,2]
  return x
lst = make()
print(lst)
# Out:
# [1, 2]

# %% [markdown]
# Printed [1,2]

# %%
#6. Mutation vs Rebinding
lst = [1 , 2]
lst . append (3)
print ( lst )
lst = [1 , 2]
lst = [9 , 10]
print ( lst )
# Out:
# [1, 2, 3]
# [9, 10]

# %% [markdown]
# [1, 2, 3]
# [9, 10]

# %%
#7. Function Arguments
def f (x) :
 x = x + 1
a = 10
f (a)
print (a)
# Out:
# 10

# %% [markdown]
# Number 10

# %%
#8. Automatic Iteration
for i in [1 , 2 , 3]:
 print (i)
# Out:
# 1
# 2
# 3

# %% [markdown]
# 3 lines

# %%
#9. Iterator Stops
it = iter ([1 , 2])
print (next(it))
print (next(it))
print (next(it))
# Out:
# 1
# 2
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# /tmp/ipython-input-314474414.py in <cell line: 0>()
#       3 print (next(it))
#       4 print (next(it))
# ----> 5 print (next(it))
#
# StopIteration:

# %% [markdown]
# Cause an error

# %%
#10. Generator Does Not Run Immediately
def demo():
  print ( " A " )
  yield 1
  print ( " B " )

x = demo ()

# %% [markdown]
# No

# %%
#11. Generator Resumes
g = demo ()
print (next(g))
print (next(g))
# Out:
#  A
# 1
#  B
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# /tmp/ipython-input-4016805315.py in <cell line: 0>()
#       2 g = demo ()
#       3 print (next(g))
# ----> 4 print (next(g))
#
# StopIteration:

# %% [markdown]
# A, 1 and B

# %%
#12. Closures Preserve Values
def outer () :
  x = 10
  def inner () :
    return x
  return inner
f = outer ()
print ( f () )
# Out:
# 10

# %% [markdown]
# A number. 10

# %%
#13. Decorators Change Behavior
def deco ( fn ) :
  def wrapper () :
    print ( " before " )
    fn ()
    print ( " after " )
  return wrapper
@deco
def hello () :
  print ( " hello " )
hello ()
# Out:
#  before
#  hello
#  after

# %% [markdown]
# 3 lines

# %%
#14. Attribute Lookup
class A :
  x = 10
a = A ()
print ( a . x )
# Out:
# 10

# %% [markdown]
# Print a number

# %%
#15. Duck Typing
class MyRange :
  def __iter__ ( self ) :
    return self
  def __next__ ( self ) :
    raise StopIteration
for x in MyRange () :
print ( x )
# Out:
#   File "/tmp/ipython-input-2180693745.py", line 8
#     print ( x )
#     ^
# IndentationError: expected an indented block after 'for' statement on line 7

# %% [markdown]
# Crash it

# %%
#Final Reflection
#The question 9 caused me a confusion.
